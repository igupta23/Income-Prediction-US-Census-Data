# %% [markdown]
# # Income Prediction From US Census Adult Income Data

# %% [markdown]
# ### 1.1 Loading Adult Income Data

# %%
#--- Import Pandas ---
import pandas as pd

#--- Read in dataset(Income Prediction Adult Data.csv) ----
#df = pd.read_csv("./Income Prediction Adult Data.csv")
df = pd.read_csv("/Users/ishika/Desktop/Projects/Income Prediction From US Census Adult Income Data/Income Prediction Adult Data.csv")

#--- Inspect data ---
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
# --- WRITE YOUR CODE FOR MODULE 1 TASK 2 ---
sumofnull = df.isnull().sum()

#--- Inspect data ---
sumofnull
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
# --- WRITE YOUR CODE FOR MODULE 1 TASK 3 ---
dtype = df.dtypes

#--- Inspect data ---
dtype
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
# --- WRITE YOUR CODE FOR MODULE 1 TASK 4 ---
numeric_features = ['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss', 'hours.per.week', 'income']
cat_features = ['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'native.country']
#--- Inspect data ---
print("\nNumeric Features:", numeric_features)
print("Categorical Features:", cat_features)
# Out:
# Numeric Features: ['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss', 'hours.per.week', 'income']
# Categorical Features: ['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'native.country']

# %%
# --- WRITE YOUR CODE FOR MODULE 1 TASK 5 ---
def replace_missing_values(column, value):
    df[column] = df[column].replace('?', value)
    return df
df = replace_missing_values('workclass', 'Unknown')
df = replace_missing_values('occupation', 'Unknown')
df = replace_missing_values('native.country', 'United-States')

#--- Inspect data ---
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90   Unknown   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66   Unknown  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
# --- WRITE YOUR CODE FOR MODULE 1 TASK 6 ---
income_map = {'<=50K': 0, '>50K': 1}
df['income'] = df['income'].replace(income_map)

#--- Inspect data ---
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90   Unknown   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66   Unknown  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %% [markdown]
# ## 2.1 Exploring Correlations in Adult Income Data

# %%
#--- Import matplotlib and  seaborn---
import seaborn as sns
import matplotlib.pyplot as plt

# --- WRITE YOUR CODE FOR MODULE 2 TASK 1 ---
corr_data = df[numeric_features].corr()
corr_plt = sns.heatmap(corr_data,annot=True, fmt = ".2f", cmap = "coolwarm")

# %% [markdown]
# ## 2.2 Visualizing Income Distribution

# %%
income_ax = sns.countplot(x=df["income"])

# %% [markdown]
# ## 2.3 Comparing Education and Income

# %%
catplt_edu = sns.catplot(x="education.num",y="income",data=df,kind="bar",palette = "muted")
# Out:
# /Users/ishika/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 2.4 Analyzing Income and Weekly Working Hours

# %%
catplt_hrs = sns.catplot(x="income",y="hours.per.week",data=df,kind="bar",palette = "muted")
# Out:
# /Users/ishika/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 2.5 Comparing Age Distribution by Income Level

# %%
hist_age = df["age"]

plt.figure(figsize=(8, 6))
plt.hist(hist_age, bins=20, color='skyblue', alpha=0.7)

plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ## 2.6 Analyzing Income Based on Relationships

# %%
catplt_relat = sns.catplot(x="relationship", y="income", data=df, kind="bar", palette="muted")
catplt_relat.set_xticklabels(rotation=45)
# Out:
# /Users/ishika/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 2.7 Analyzing Income Based on Gender

# %%
catplt_sex = sns.catplot(x="sex", y="income", data=df, kind="bar",palette="muted")
# Out:
# /Users/ishika/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 2.8 Analyzing Income Based on Marital Status

# %%
catplt_married  = sns.catplot(x="marital.status", y="income", data=df, kind="bar", palette="muted")
catplt_married.set_xticklabels(rotation=45)
# Out:
# /Users/ishika/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 2.9 Analyzing Income Based on Workclass

# %%
catplt_wrkcls  = sns.catplot(x="workclass", y="income", data=df, kind="bar",
                       palette="muted")
catplt_wrkcls.set_xticklabels(rotation=45)
# Out:
# /Users/ishika/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 3.1 Data Preprocessing for Relationship and Gender
# A modified 'data' DataFrame by encoding the 'sex' attribute from strings 'Male' and 'Female' to numerical values 0 and 1, respectively. Furthermore, it consolidates the 'marital.status' attribute into two categories 'Married' and 'Single' for improved analysis and replaces these categories with binary values 1 and 0, respectively. This preprocessing is vital for refining and simplifying the relationship and gender attributes to enhance the accuracy and interpretability of the data for further analysis in the US Census adult income data

# %%
data  = df.copy()
data ["sex"] = data ["sex"].map({"Male": 0, "Female": 1})
data ["marital.status"] = data["marital.status"].replace(['Never-married', 'Divorced', 'Separated', 'Widowed'], 'Single')
data ["marital.status"] = data["marital.status"].replace(['Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse'], 'Married')
data ["marital.status"] = data["marital.status"].map({"Married": 1, "Single": 0})
data
# Out:
#        age workclass  fnlwgt     education  education.num  marital.status  \
# 0       90   Unknown   77053       HS-grad              9               0
# 1       82   Private  132870       HS-grad              9               0
# 2       66   Unknown  186061  Some-college             10               0
# 3       54   Private  140359       7th-8th              4               0
# 4       41   Private  264663  Some-college             10               0
# ...    ...       ...     ...           ...            ...             ...
# 32556   22   Private  310152  Some-college             10               0
# 32557   27   Private  257302    Assoc-acdm             12               1
# 32558   40   Private  154374       HS-grad              9               1
# 32559   58   Private  151910       HS-grad              9               0
# 32560   22   Private  201490       HS-grad              9               0
#
#               occupation   relationship   race  sex  capital.gain  \
# ...

# %% [markdown]
# ## 3.2 Removing Certain Attributes for Data Simplification

# %%
data  = data.drop(labels=["workclass", "education", "occupation", "relationship", "race", "native.country"], axis=1)
data
# Out:
#        age  fnlwgt  education.num  marital.status  sex  capital.gain  \
# 0       90   77053              9               0    1             0
# 1       82  132870              9               0    1             0
# 2       66  186061             10               0    1             0
# 3       54  140359              4               0    1             0
# 4       41  264663             10               0    1             0
# ...    ...     ...            ...             ...  ...           ...
# 32556   22  310152             10               0    0             0
# 32557   27  257302             12               1    1             0
# 32558   40  154374              9               1    0             0
# 32559   58  151910              9               0    1             0
# 32560   22  201490              9               0    0             0
#
#        capital.loss  hours.per.week  income
# 0              4356              40       0
# 1              4356              18       0
# ...

# %% [markdown]
# ## 4.1  Data Splitting for Modeling in Adult Income Data
# The 'data' DataFrame is split into training and validation sets for modeling. The feature set 'x' is generated by dropping the 'income' column, while the target variable 'y' consists solely of the 'income' column. Utilizing the train_test_split function from sklearn.model_selection, the data is split into 80% training data ('X_train' and 'Y_train') and 20% validation data ('X_validation' and 'Y_validation'). This step is essential for training and evaluating models in the US Census adult income data analysis

# %%
from sklearn.model_selection import  train_test_split

x = data.drop("income", axis=1)
y = data["income"]
X_train, X_validation, Y_train, Y_validation  = train_test_split(x, y, train_size=0.8, test_size=0.2, random_state=7)

#--- Inspect data ---
X_train
# Out:
#        age  fnlwgt  education.num  marital.status  sex  capital.gain  \
# 12011   60  366531             11               0    1             0
# 23599   44  228729              9               1    0             0
# 23603   37   95855              7               0    1             0
# 6163    35  178322             11               1    0             0
# 14883   60  122276              3               1    0             0
# ...    ...     ...            ...             ...  ...           ...
# 5699    32  158784              4               0    1             0
# 10742   27  162343             13               1    0             0
# 16921   66   86010              6               0    1             0
# 25796   33  279173              9               1    0             0
# 28847   58  224854              9               0    1             0
#
#        capital.loss  hours.per.week
# 12011             0              40
# 23599             0              40
# ...

# %% [markdown]
# ## 4.2 Training and Evaluating Logistic Regression Model
# Logistic Regression model is trained using the training data 'X_train' and 'Y_train' and then assessing the model's performance using cross-validation with 10 folds. The cross_val_score function from sklearn.model_selection assesses the Logistic Regression model's performance and computes the mean accuracy score over the 10 folds. This evaluation is crucial for understanding the model's predictive capability in the US Census adult income data analysis.

# %%
#--- Import LogisticRegression ---
from sklearn.linear_model import LogisticRegression
#--- Import cross_val_score from sklearn.model_selection ---
from sklearn.model_selection import cross_val_score

lr_model = LogisticRegression()
lr_model.fit(X_train, Y_train)
cv_results = cross_val_score(lr_model, X_train, Y_train, cv=10)
lr_mean_score  = round(cv_results.mean(), 4)

#--- Inspect data ---
lr_mean_score
# Out:
# 0.7966

# %% [markdown]
# ## 4.3 Training and Evaluating Linear Discriminant Analysis Model
# Linear Discriminant Analysis (LDA) model is trained using the training data 'X_train' and 'Y_train' and then assessing the model's performance via 10-fold cross-validation. The cross_val_score function from sklearn.model_selection is used to evaluate the LDA model's accuracy across the 10 folds. This evaluation is vital for understanding the model's performance in predicting income classes within the US Census adult income data analysis.

# %%
#--- Import LinearDiscriminantAnalysis ---
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

ldr_model = LinearDiscriminantAnalysis()
ldr_model.fit(X_train, Y_train)
cv_results = cross_val_score(ldr_model, X_train, Y_train, cv=10)
ldr_mean_score  = ldr_mean_score = round(cv_results.mean(), 4)

#--- Inspect data ---
ldr_mean_score
# Out:
# 0.8297

# %% [markdown]
# ## 4.4 Training and Evaluating K-Nearest Neighbors Classifier
# K-Nearest Neighbors (KNN) classification model is trained using the training data 'X_train' and 'Y_train'. Subsequently, the model's performance is assessed by utilizing the cross_val_score function from sklearn.model_selection, evaluating the KNN model's accuracy across 10-fold cross-validation. This evaluation is important to gauge the KNN model's predictive performance in determining income classes within the US Census adult income data analysis.

# %%
#--- Import KNeighborsClassifier ---
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier()
knn_model.fit(X_train, Y_train)
cv_results = cross_val_score(knn_model, X_train, Y_train, cv=10)
knn_mean_score  = round(cv_results.mean(), 4)

#--- Inspect data ---
knn_mean_score
# Out:
# 0.7744

# %% [markdown]
# ## 4.5 Training and Evaluating Decision Tree Classifier
# Decision Tree Classifier is trained using the training data 'X_train' and 'Y_train', followed by assessing the model's performance through 10-fold cross-validation. The cross_val_score function from sklearn.model_selection is used to compute the Decision Tree Classifier's mean accuracy across the 10 folds. This evaluation is crucial for understanding the Decision Tree model's performance in predicting income classes within the US Census adult income data analysis.

# %%
#--- Import DecisionTreeClassifier ---
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, Y_train)
cv_results = cross_val_score(dt_model, X_train, Y_train, cv=10)
dt_mean_score = round(cv_results.mean(), 4)

#--- Inspect data ---
dt_mean_score
# Out:
# 0.8093

# %% [markdown]
# ## 4.6 Training and Evaluating Gaussian Naive Bayes Classifier
# Gaussian Naive Bayes (NB) is trained classifier using the training data 'X_train' and 'Y_train', followed by assessing the model's performance via 10-fold cross-validation. The cross_val_score function from sklearn.model_selection is utilized to determine the Gaussian NB model's mean accuracy across the 10 folds. This evaluation is essential for comprehending the model's predictive performance in determining income classes within the US Census adult income data analysis.

# %%
#--- Import GaussianNB ---
from sklearn.naive_bayes import GaussianNB

gb_model = GaussianNB()
gb_model.fit(X_train, Y_train)
cv_results = cross_val_score(gb_model, X_train, Y_train, cv=10)
gb_mean_score = round(cv_results.mean(), 4)

#--- Inspect data ---
gb_mean_score
# Out:
# 0.7943

# %% [markdown]
# ## 4.7 Model Optimization using GridSearchCV
# GridSearchCV from sklearn.model_selection is utilized to optimize the Linear Discriminant Analysis (LDA) model's performance. The parameters for 'solver' are specified as 'svd', 'lsqr', and 'eigen'. GridSearchCV performs a search across the defined parameters within a 5-fold cross-validation setup using the training data ('X_train' and 'Y_train'). After the grid search, 'best_params' capture the most optimal parameters, and 'best_score' denotes the highest achieved score among the parameter combinations. Additionally, the 'best_ldr_model' variable holds the optimized LDA model with the best parameters obtained from the grid search, enhancing the model's performance within the US Census adult income data analysis.

# %%
#--- Import GridSearchCV ---
from sklearn.model_selection import GridSearchCV

parameters = {'solver': ['svd', 'lsqr', 'eigen']}

grid_search = GridSearchCV(ldr_model, parameters, cv=5)
grid_search.fit(X_train, Y_train)

# Get the best parameter values
best_params = grid_search.best_params_
best_score = grid_search.best_score_

best_ldr_model = grid_search.best_estimator_

#--- Inspect data ---
best_score
# Out:
# 0.8295070726916245

# %% [markdown]
# ## 4.8 Evaluating Model Performance on Validation Data
# The performance of the selected model is evaluated from previous training assessments, using the validation dataset 'X_validation' and 'Y_validation'. The accuracy_score function from sklearn.metrics determines the accuracy by comparing the predicted values ('y_pred') to the actual values ('Y_validation'). Additionally, the confusion_matrix and classification_report functions from sklearn.metrics are used to generate a confusion matrix and a comprehensive classification report, respectively. These metrics provide insights into the model's predictive accuracy and misclassifications, aiding in assessing the model's performance in predicting income classes within the US Census adult income data analysis.

# %%
#--- Import accuracy_score, confusion_matrix, classification_report from sklearn.metrics ---
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# --- WRITE YOUR CODE FOR MODULE 4 TASK 8 ---
y_pred = best_ldr_model.predict(X_validation)
accuracy = accuracy_score(Y_validation, y_pred)
cm = confusion_matrix(Y_validation, y_pred)
cr = classification_report(Y_validation, y_pred)

#--- Inspect data ---
accuracy
# Out:
# 0.831874712114233

# %% [markdown]
# ## 4.9 Evaluating Precision, Recall, and F1-Score
# Precision, recall, and F1-score metrics are calculated for the model using the validation dataset. The precision_score, recall_score, and f1_score functions from sklearn.metrics are employed to compute precision, recall, and the F1-score, respectively. These metrics offer insights into the model's precision (accuracy of positive predictions), recall (sensitivity to actual positives), and the balance between precision and recall captured by the F1-score. These calculations further aid in understanding the model's performance in predicting income classes within the US Census adult income data analysis.

# %%
#--- Import precision_score, recall_score, f1_score from sklearn.metrics ---
from sklearn.metrics import precision_score, recall_score, f1_score

# Calculate precision
precision = precision_score(Y_validation, y_pred)

# Calculate recall
recall = recall_score(Y_validation, y_pred)

# Calculate F1-score
F1_score = f1_score(Y_validation, y_pred)



#--- Inspect data ---
precision,recall,F1_score
# Out:
# (0.6967071057192374, 0.5190445448676565, 0.5948945615982242)

# %% [markdown]
# ## 4.10 Predicting Income Class on New Data
# The best-performing model determined from prior evaluations is utilized to predict the income class for new data. The new data, structured as a NumPy array, comprises features related to an individual's characteristics, such as age, fnlwgt, education years, among others. The model (which needs to be replaced by the specific best model selected previously) predicts the income class based on these features. The 'predict' method applies the model to the new data to generate the predicted income class, aiding in understanding how accurately the model can predict income status for a new individual in the context of the US Census adult income data analysis.

# %%
import numpy as np
new_data = pd.DataFrame([[74, 88638, 16, 0, 1, 0, 683, 20]],
                    columns=['age', 'fnlwgt', 'education.num', 'marital.status', 'sex', 'capital.gain', 'capital.loss', 'hours.per.week'])
prediction = best_ldr_model.predict(new_data)

#--- Inspect data ---
prediction
# Out:
# array([0])
